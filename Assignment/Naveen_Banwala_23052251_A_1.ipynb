.predict(X)

plt.figure(figsize=(8,5))
plt.scatter(X, y, s=5, label="Actual Data")
plt.plot(X, y_pred_linear, color='red', label="Regression Line")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()

# %%
# C) Evaluate the model using metrics mean_average_error, mean_squared_error, root_mean_squared_error and r2_score

mae = mean_absolute_error(y, y_pred_linear)
mse = mean_squared_error(y, y_pred_linear)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred_linear)

print("Linear Regression Evaluation Metrics")
print("MAE  :", mae)
print("MSE  :", mse)
print("RMSE :", rmse)
print("R2   :", r2)
# Out:
# Linear Regression Evaluation Metrics
# MAE  : 176546263621.17474
# MSE  : 4.0099075177481985e+22
# RMSE : 200247534760.06137
# R2   : 0.8045852730076655

# %%
# For each value of degrees of equation = 2, 3, 4, 5, 6 and 7 separately [for y = f(x)], attempt question D, E and F:

# %%
# D) Develop Polynomial Regression Models based on x and y data and provide the Polynomial Equations

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

def polynomial_regression(degree):
    # Transform X to polynomial features
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(X)

    # Fit linear regression on polynomial features
    model = LinearRegression()
    model.fit(X_poly, y)

    # Predict
    y_pred = model.predict(X_poly)

    # Evaluation metrics
    mae = mean_absolute_error(y, y_pred)
    mse = mean_squared_error(y, y_pred)
    rmse = np.sqrt(mse)  # fixed here
    r2 = r2_score(y, y_pred)



    
# E) Visualize the Model

# F) Evaluate the model using metrics mean_average_error, mean_squared_error, root_mean_squared_error and r2_score


    print(f"\nPolynomial Regression Degree {degree}")
    print("MAE  :", mae)
    print("MSE  :", mse)
    print("RMSE :", rmse)
    print("R2   :", r2)

    # Plot
    plt.figure(figsize=(8,5))
    plt.scatter(X, y, s=5, label="Actual Data")
    plt.plot(X, y_pred, color='red', label=f"Degree {degree} Fit")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title(f"Polynomial Regression (Degree {degree})")
    plt.legend()
    plt.show()

    return model

# Store models for degrees 2 to 7
poly_models = {}
for d in range(2, 8):
    poly_models[d] = polynomial_regression(d)
# Out:
# Polynomial Regression Degree 2
# MAE  : 84471245858.68353
# MSE  : 1.4774458597698758e+22
# RMSE : 121550230759.54549
# R2   : 0.9279996663127493
# Polynomial Regression Degree 3
# MAE  : 87524024328.80664
# MSE  : 1.3434425281463812e+22
# RMSE : 115906968217.89366
# R2   : 0.9345300474622811
# Polynomial Regression Degree 4
# MAE  : 73723520150.49922
# MSE  : 1.0018942328921733e+22
# RMSE : 100094666835.55989
# R2   : 0.9511747123520287
# Polynomial Regression Degree 5
# MAE  : 63944467355.4145
# MSE  : 9.012523586791379e+21
# RMSE : 94934311957.22324
# R2   : 0.9560792903968564
# Polynomial Regression Degree 6
# MAE  : 62849405717.3026
# MSE  : 9.23357428840187e+21
# RMSE : 96091489156.95848
# R2   : 0.9550020445422952
# Polynomial Regression Degree 7
# MAE  : 64747565446.14701
# MSE  : 9.318774972774299e+21
# RMSE : 96533802228.93066
# R2   : 0.9545868362512684

# %%
#PART G–H: RANDOM FOREST REGRESSION
# G) Train Random Forest Model

rf_model = RandomForestRegressor(
    n_estimators=300,
    random_state=42
)

rf_model.fit(X, y)
y_pred_rf = rf_model.predict(X)

# %%
# H - Random Forest -> Visualize the Model

plt.figure(figsize=(8,5))
plt.scatter(X, y, s=5, label="Actual Data")
plt.scatter(X, y_pred_rf, s=5, label="Predicted Data")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Random Forest Regression")
plt.legend()
plt.show()

# %%
# I) Evaluate the model using metrics accuracy, classification Report (consisting of predicted value, actual value, Mean-Square, R2_Score)

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Assuming y_pred_rf is already predicted by your Random Forest model
print("Random Forest Regression Evaluation Metrics")
print("MAE  :", mean_absolute_error(y, y_pred_rf))
print("MSE  :", mean_squared_error(y, y_pred_rf))
rmse = np.sqrt(mean_squared_error(y, y_pred_rf))  # corrected here
print("RMSE :", rmse)
print("R2   :", r2_score(y, y_pred_rf))
# Out:
# Random Forest Regression Evaluation Metrics
# MAE  : 3531443487.384454
# MSE  : 3.820249413954744e+19
# RMSE : 6180816624.002645
# R2   : 0.9998138278768359

# %%
#  Part - Justify 

# 1 Linear Regression

# R²: 0.8046 → explains ~80% of the variance.

# MAE/RMSE: Extremely high.

# Observation: The model underfits the data because it cannot capture any nonlinear patterns in your dataset.



# 2️ Polynomial Regression (Degrees 2–7)
# Degree	MAE	RMSE	R²	Observation
# | Degree | MAE            | RMSE            | R²    | Observation                                          |
# | ------ | -------------- | --------------- | ----- | ---------------------------------------------------- |
# | 2      | 84,471,245,859 | 121,550,230,760 | 0.928 | Better than linear, captures some curvature.         |
# | 3      | 87,524,024,329 | 115,906,968,218 | 0.935 | Slight improvement in R².                            |
# | 4      | 73,723,520,150 | 100,094,666,836 | 0.951 | Significantly better fit.                            |
# | 5      | 63,944,467,355 | 94,934,311,957  | 0.956 | Best fit among polynomials.                          |
# | 6      | 62,849,405,717 | 96,091,489,157  | 0.955 | Slightly worse than degree 5 (possible overfitting). |
# | 7      | 64,747,565,446 | 96,533,802,229  | 0.955 | No improvement; overfitting likely.                  |




# Observation:

# Degree 5 polynomial gives the highest R² (0.956) and lowest MAE/RMSE among polynomial models.

# Degrees 6 and 7 do not improve accuracy much → adding more complexity leads to overfitting.

# 3️ Random Forest Regression

# R²: 0.9998 → explains almost all the variance.

# MAE/RMSE: Extremely low compared to all linear and polynomial models.

# Observation: Random Forest captures nonlinear patterns and interactions extremely well.





#  Conclusion: Best Model

# Random Forest Regression is the best model.






# Justification:

# Accuracy: R² ≈ 0.9998 → almost perfect fit.

# Error Metrics: MAE and RMSE are orders of magnitude lower than Linear or Polynomial models.

# Flexibility: Handles nonlinear relationships and interactions without manually choosing polynomial degrees.

# Polynomial Regression Limitation: Even degree 5 (best among polynomials) has R² ≈ 0.956 → not as accurate as Random Forest. Also, higher-degree polynomials risk overfitting.






# Summary Table for Comparison

# | Model               | MAE             | RMSE            | R²     |
# | ------------------- | --------------- | --------------- | ------ |
# | Linear Regression   | 176,546,263,621 | 200,247,534,760 | 0.8046 |
# | Polynomial Degree 5 | 63,944,467,355  | 94,934,311,957  | 0.956  |
# | Random Forest       | 3,531,443,487   | 6,180,816,624   | 0.9998 |


# Verdict: Random Forest is the model you should accept.

# Near-Perfect Fit: The $R^2$ of 0.9998 means the model explains 99.98% of the variance. 
# It is significantly more accurate than the best Polynomial model ($R^2 = 0.956$).
# Drastic Error Reduction: The Mean Absolute Error (MAE) for Random Forest is roughly 3.5 Billion, whereas the best Polynomial model still has an error of 63.9 Billion. 
# The Random Forest is nearly 18 times more accurate.
# No Manual Tuning: Polynomial models require you to guess the "degree" (complexity).
# If you choose too low, you underfit; too high, and you overfit. 
# Random Forest automatically adapts to the data's complexity.Handling the Trend: Your data grows exponentially but has local fluctuations. While Polynomials try to "smooth" the curve (missing local details), Random Forest captures the actual behavior of the data points more precisely.
