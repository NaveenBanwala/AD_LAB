# Convert lists to numpy arrays
X = np.array(x_list).reshape(-1, 1)
y = np.array(y_list)

# %%
linear_model = LinearRegression()
linear_model.fit(X, y)

m = linear_model.coef_[0]
c = linear_model.intercept_

print("Linear Regression Equation:")
print(f"y = {m:.6e}x + {c:.6e}")
# Out:
# Linear Regression Equation:
# y = 1.647533e+08x + -1.994620e+11

# %%
# B) Visualize the regression line on a scatter plot of the data

y_pred_linear = linear_model.predict(X)

plt.figure(figsize=(8,5))
plt.scatter(X, y, s=5, label="Actual Data")
plt.plot(X, y_pred_linear, color='red', label="Regression Line")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()

# %%
# C) Evaluate the model using metrics mean_average_error, mean_squared_error, root_mean_squared_error and r2_score

mae = mean_absolute_error(y, y_pred_linear)
mse = mean_squared_error(y, y_pred_linear)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred_linear)

print("Linear Regression Evaluation Metrics")
print("MAE  :", mae)
print("MSE  :", mse)
print("RMSE :", rmse)
print("R2   :", r2)
# Out:
# Linear Regression Evaluation Metrics
# MAE  : 206060361799.47247
# MSE  : 5.8956198021726885e+22
# RMSE : 242808974343.46796
# R2   : 0.7398146549872603

# %%
# For each value of degrees of equation = 2, 3, 4, 5, 6 and 7 separately [for y = f(x)], attempt question D, E and F:

# %%
# D) Develop Polynomial Regression Models based on x and y data and provide the Polynomial Equations

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

def polynomial_regression(degree):
    # Transform X to polynomial features
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(X)

    # Fit linear regression on polynomial features
    model = LinearRegression()
    model.fit(X_poly, y)

    # Predict
    y_pred = model.predict(X_poly)

    # Evaluation metrics
    mae = mean_absolute_error(y, y_pred)
    mse = mean_squared_error(y, y_pred)
    rmse = np.sqrt(mse)  # fixed here
    r2 = r2_score(y, y_pred)



    
# E) Visualize the Model

# F) Evaluate the model using metrics mean_average_error, mean_squared_error, root_mean_squared_error and r2_score


    print(f"\nPolynomial Regression Degree {degree}")
    print("MAE  :", mae)
    print("MSE  :", mse)
    print("RMSE :", rmse)
    print("R2   :", r2)

    # Plot
    plt.figure(figsize=(8,5))
    plt.scatter(X, y, s=5, label="Actual Data")
    plt.plot(X, y_pred, color='red', label=f"Degree {degree} Fit")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title(f"Polynomial Regression (Degree {degree})")
    plt.legend()
    plt.show()

    return model

# Store models for degrees 2 to 7
poly_models = {}
for d in range(2, 8):
    poly_models[d] = polynomial_regression(d)
# Out:
# Polynomial Regression Degree 2
# MAE  : 181889625242.01935
# MSE  : 5.450493217127671e+22
# RMSE : 233462913909.84717
# R2   : 0.7594589702569796
# Polynomial Regression Degree 3
# MAE  : 157348802376.11807
# MSE  : 3.5936048317108505e+22
# RMSE : 189568057217.2129
# R2   : 0.841407121837544
# Polynomial Regression Degree 4
# MAE  : 135535699687.80548
# MSE  : 3.329127809736785e+22
# RMSE : 182458976477.91367
# R2   : 0.8530790151276956
# Polynomial Regression Degree 5
# MAE  : 148219024205.68478
# MSE  : 3.662508165487847e+22
# RMSE : 191376805425.52295
# R2   : 0.838366281642135
# Polynomial Regression Degree 6
# MAE  : 151450875819.19443
# MSE  : 3.4227707239567767e+22
# RMSE : 185007316719.00916
# R2   : 0.8489463683896294
# Polynomial Regression Degree 7
# MAE  : 135478741835.59468
# MSE  : 2.6829330624691288e+22
# RMSE : 163796613593.47845
# R2   : 0.8815968654818339

# %%
#PART G–H: RANDOM FOREST REGRESSION
# G) Train Random Forest Model

rf_model = RandomForestRegressor(
    n_estimators=300,
    random_state=42
)

rf_model.fit(X, y)
y_pred_rf = rf_model.predict(X)

# %%
# H - Random Forest -> Visualize the Model

plt.figure(figsize=(8,5))
plt.scatter(X, y, s=5, label="Actual Data")
plt.scatter(X, y_pred_rf, s=5, label="Predicted Data")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Random Forest Regression")
plt.legend()
plt.show()

# %%
# I) Evaluate the model using metrics accuracy, classification Report (consisting of predicted value, actual value, Mean-Square, R2_Score)

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Assuming y_pred_rf is already predicted by your Random Forest model
print("Random Forest Regression Evaluation Metrics")
print("MAE  :", mean_absolute_error(y, y_pred_rf))
print("MSE  :", mean_squared_error(y, y_pred_rf))
rmse = np.sqrt(mean_squared_error(y, y_pred_rf))  # corrected here
print("RMSE :", rmse)
print("R2   :", r2_score(y, y_pred_rf))
# Out:
# Random Forest Regression Evaluation Metrics
# MAE  : 5178609141.042111
# MSE  : 8.29281271278886e+19
# RMSE : 9106488188.532866
# R2   : 0.9996340217976729

# %%
# ==============================================================================
# MODEL PERFORMANCE & JUSTIFICATION REPORT
# ==============================================================================

# 1. LINEAR REGRESSION ANALYSIS
# ------------------------------------------------------------------------------
# Equation: y = 1.647533e+08x - 1.994620e+11
# R-Squared (R2) : 0.7398
# MAE            : 206,060,361,799.47
# RMSE           : 242,808,974,343.47
#
# Observation: The model UNDERFITS the data. A simple linear line cannot 
# capture the non-linear curve or growth patterns in the dataset.


# 2. POLYNOMIAL REGRESSION COMPARISON (DEGREES 2-7)
# ------------------------------------------------------------------------------
# | Degree | MAE             | RMSE            | R2    | Observation           |
# |--------|-----------------|-----------------|-------|-----------------------|
# | 2      | 181,889,625,242 | 233,462,913,910 | 0.759 | Marginal improvement  |
# | 3      | 157,348,802,376 | 189,568,057,217 | 0.841 | Better trend capture  |
# | 4      | 135,535,699,688 | 182,458,976,478 | 0.853 | **Best Stable Fit** |
# | 5      | 148,219,024,206 | 191,376,805,426 | 0.838 | Error increases       |
# | 6      | 151,450,875,819 | 185,007,316,719 | 0.849 | High instability      |
# | 7      | 135,478,741,836 | 163,796,613,593 | 0.882 | Potential Overfitting |


# 3. OVERFITTING ANALYSIS
# ------------------------------------------------------------------------------
# Verdict: Signs of OVERFITTING begin at Degree 5.



# Evidence: 
# In a healthy model, adding complexity should consistently reduce error. 
# Here, MAE increases from ~135B (Deg 4) to ~148B (Deg 5), which indicates 
# the model is starting to react to random noise rather than the real trend. 
# While Degree 7 shows a higher R2, it is likely "memorizing" specific data 
# points and will fail to predict new data accurately.


# 4. CONCLUSION: BEST MODEL SELECTION
# ------------------------------------------------------------------------------
# Recommendation: Polynomial Regression Degree 4
#
# Justification:
# 1. Accuracy: Explains 85.3% of the variance ($R^2 = 0.8531$).
# 2. Precision: Reduces Mean Absolute Error (MAE) by ~70 Billion compared to Linear.
# 3. Stability: It is the highest degree that shows a consistent reduction 
#    in error before the model becomes unstable at Degree 5.
#
# Final Verdict: Select Degree 4 for reliable future predictions.
# ==============================================================================
